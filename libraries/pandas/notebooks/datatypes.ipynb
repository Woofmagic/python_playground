# %%
import pandas as pd

# %%
data = {
    "A": [4, 5, 6, 7],
    "B": [4, 2, 6, 2]}

# %%
data = pd.DataFrame(data)

# %%
data['B'].min()
# Out:
# 2

# %%
data['B'].notna()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# Name: B, dtype: bool

# %%
data['B'].nunique()
# Out:
# 3
