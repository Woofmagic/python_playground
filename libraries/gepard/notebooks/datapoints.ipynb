# %%
import gepard as g

# %%
g.__version__
# Out:
# '0.9.10'

# %% [markdown]
# Absolutely *awesome* list of `DataSet`s from the documentation: https://gepard.phy.hr/datasets.html

# %%
g.list_data([5, 32])
# Out:
# [  5]   HERMES  18      ALUI  0909.3587 Table 2
# [ 32]   HERMES  36        AC  0909.3587 Table 4

# %% [markdown]
# We actually used the data above by basically manually extracting it in this repository: [Woofmagic/gpd_dnn](https://github.com/Woofmagic/gpd_dnn/tree/main).

# %% [markdown]
# The main thing that we want is this:
#
# > Finally, there is a convenient method df which transforms any DataSet into a corresponding pandas DataFrame, which makes it easy to perform various dataset analyses.

# %%
hermes_tables_2 = g.dset[5]
hermes_tables_4 = g.dset[32]

# %%
hermes_tables_2
# Out:
# DataSet with 18 points

# %% [markdown]
# Correctly cross-checked with other repository.

# %%
hermes_tables_4
# Out:
# DataSet with 36 points

# %% [markdown]
# Nice. That's very convienent.

# %%
hermes_tables_2.df()
# Out:
#    observable collaboration  id     x   eta        xi    xB    Q2     t    tm  \
# 0        ALUI        HERMES   5  None  None  0.036269  0.07  1.71 -0.02  0.02
# 1        ALUI        HERMES   5  None  None  0.047120  0.09  2.22 -0.04  0.04
# 2        ALUI        HERMES   5  None  None  0.052632  0.10  2.44 -0.08  0.08
# 3        ALUI        HERMES   5  None  None  0.058201  0.11  2.72 -0.14  0.14
# 4        ALUI        HERMES   5  None  None  0.063830  0.12  3.13 -0.26  0.26
# 5        ALUI        HERMES   5  None  None  0.063830  0.12  3.63 -0.46  0.46
# 6        ALUI        HERMES   5  None  None  0.025641  0.05  1.34 -0.10  0.10
# 7        ALUI        HERMES   5  None  None  0.036269  0.07  1.78 -0.09  0.09
# 8        ALUI        HERMES   5  None  None  0.047120  0.09  2.30 -0.11  0.11
# 9        ALUI        HERMES   5  None  None  0.058201  0.11  2.92 -0.12  0.12
# 10       ALUI        HERMES   5  None  None  0.086957  0.16  4.04 -0.16  0.16
# ...
